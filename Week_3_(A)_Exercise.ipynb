# %% [markdown]
# <a href="https://colab.research.google.com/github/nkumanning/Spring-Course-24/blob/main/Week_3_(A)_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Module 1 Exercises

# %% [markdown]
# ## Python Basics

# %% [markdown]
# 1. Create a variable that has an integer value and another variable that has a float value.

# %%
x = 7
y = 14.6

# %% [markdown]
# 2. Complete the code that prints the sum of the two variables.

# %%
print(x + y)
# Out:
# 21.6

# %% [markdown]
# 3. Write the code to find the type of data each variable contains.

# %%
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# 4. Create a list with all the days of the week. Print the contents of the list.

# %%
week = 'Sunday, Monday, Tuesday, Wedneday, Thursday, Friday, Saturday'
print(week)
# Out:
# Sunday, Monday, Tuesday, Wedneday, Thursday, Friday, Saturday

# %% [markdown]
# ## Importing and Inspecting Data

# %% [markdown]
# 1. Complete the code to import the Pandas library.

# %%
import pandas as pd

# %% [markdown]
# 2. Import the <b>axisdata.csv</b> file and store the dataset in a variable named: sales. This dataset includes information about a sales team for a local company. The dataset includes the following columns:
#
#     * Fname: first name of the sales person
#     * Lname: last name of the sales person
#     * Gender: gender of the sales person
#     * Hours Worked: hours worked in the last week
#     * SalesTraining: if sales person ever received sales training
#     * Years Experience: total years of sales experience
#     * Cars Sold: number of cars sold in the last week

# %%
sales = pd.read_csv('axisdata.csv')

sales.head()
# Out:
#      Fname      Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 0     Jada   Walters       F            39             N                 3
# 1   Nicole  Henderson      F            46             N                 3
# 2    Tanya      Moore      F            42             Y                 4
# 3  Ronelle    Jackson      F            38             Y                 5
# 4     Brad      Sears      M            33             N                 4
#
#    Cars Sold
# 0          2
# 1          6
# 2          6
# 3          3
# 4          2

# %% [markdown]
# 3. Inspect the first 10 rows of the dataset "sales". What is the full name of the very first sales person?

# %%
sales.head(10)

#Jada Walters
# Out:
#      Fname      Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 0     Jada   Walters       F            39             N                 3
# 1   Nicole  Henderson      F            46             N                 3
# 2    Tanya      Moore      F            42             Y                 4
# 3  Ronelle    Jackson      F            38             Y                 5
# 4     Brad      Sears      M            33             N                 4
# 5   Jackie     Rogers      F            45             Y                 5
# 6   Oliver     Vaughn      M            46             N                 5
# 7    Carla       Sapp      F            39             Y                 3
# 8    Karen      Moore      F            33             Y                 2
# 9    Roger       Kane      M            38             N                 4
#
#    Cars Sold
# 0          2
# 1          6
# 2          6
# 3          3
# 4          2
# 5          3
# 6          3
# 7          6
# 8          5
# 9          5

# %% [markdown]
# 4. Inspect the last 5 rows of the dataset sales. How many rows are there in total in our dataset?

# %%
sales.tail()

#there are 998 rows
# Out:
#         Fname     Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 994    Victor      Kane      M            22             Y                 5
# 995   Charles    Turner      M            45             N                 1
# 996    August  Franklin      F            34             Y                 4
# 997  Victoria    Rogers      F            29             N                 5
# 998      Mike   Gerardo      M            20             N                 3
#
#      Cars Sold
# 994          4
# 995          4
# 996          3
# 997          1
# 998          3

# %% [markdown]
# 5. Complete the code below to find some meta information for our dataset. How many columns are there total in the dataset? In which column(s) do we have missing/NaN values?

# %%
sales.info()

# there are 7 columns
# 999 non-null = all of them have values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fname             999 non-null    object
#  1   Lname             999 non-null    object
#  2   Gender            999 non-null    object
#  3   Hours Worked      999 non-null    int64
#  4   SalesTraining     999 non-null    object
#  5   Years Experience  999 non-null    int64
#  6   Cars Sold         999 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 54.8+ KB

# %% [markdown]
# 6. Write the code to get summary statistics for our dataset. What is the maximum value in column <b>Hours Worked</b>? What is the minimum value in column <b>Years Experience</b>? What is the average value in column <b>Cars Sold</b>?

# %%
sales.describe()

# summary statistics
# Out:
#        Hours Worked  Years Experience   Cars Sold
# count    999.000000        999.000000  999.000000
# mean      33.727728          3.026026    3.922923
# std        8.223454          1.394709    1.527000
# min       20.000000          1.000000    1.000000
# 25%       27.000000          2.000000    3.000000
# 50%       34.000000          3.000000    4.000000
# 75%       41.000000          4.000000    5.000000
# max       48.000000          5.000000    7.000000

# %%
sales.max()

# maximum value in Hours Worked is 48
# Out:
# Fname                 india
# Lname               Withers
# Gender                    M
# Hours Worked             48
# SalesTraining             Y
# Years Experience          5
# Cars Sold                 7
# dtype: object

# %%
sales.min()

# minimum value in Years Experience is 1
# Out:
# Fname               Aaron
# Lname               Adams
# Gender                  F
# Hours Worked           20
# SalesTraining           N
# Years Experience        1
# Cars Sold               1
# dtype: object

# %% [markdown]
# ## Indexing and Slicing Data

# %% [markdown]
# 1. Using the dataset from the previous section ("sales"), select the <b>Lname</b> column without using iloc or loc. What is the last name of the second sales person?

# %%
sales.Lname

# Rogers
# Out:
# 0       Walters
# 1      Henderson
# 2          Moore
# 3        Jackson
# 4          Sears
#          ...
# 994         Kane
# 995       Turner
# 996     Franklin
# 997       Rogers
# 998      Gerardo
# Name: Lname, Length: 999, dtype: object

# %% [markdown]
# 2. Select the <b>Lname</b> column again - this time, use the code that outputs the column as a Pandas DataFrame.

# %%
sales['Lname']
# Out:
# 0       Walters
# 1      Henderson
# 2          Moore
# 3        Jackson
# 4          Sears
#          ...
# 994         Kane
# 995       Turner
# 996     Franklin
# 997       Rogers
# 998      Gerardo
# Name: Lname, Length: 999, dtype: object

# %% [markdown]
# 3. Look at the sales dataset at index position 100 with the iloc operation. How many hours has this sales person worked in the past week?

# %%
sales.iloc[100]

# 23 hours
# Out:
# Fname                 Frank
# Lname               Johnson
# Gender                    M
# Hours Worked             23
# SalesTraining             N
# Years Experience          5
# Cars Sold                 1
# Name: 100, dtype: object

# %% [markdown]
# 4. Look at the sales dataset at index position 35 with the iloc operation. Only select for the column "Cars Sold". How many cars did this sales person sell in the past week?

# %%
sales.iloc[35, [6]]

# 4 cars
# Out:
# Cars Sold    4
# Name: 35, dtype: object

# %% [markdown]
# 5. Select the last 7 rows and the columns: fname, gender, and years experience with the iloc operation. How many women are there in this subset? How many years of experience does the last sales person have?

# %%
sales.iloc[-7:, [0, 2, 5]]

# 2 women
# 3 years of experience
# Out:
#         Fname Gender  Years Experience
# 992      Adam      M                 4
# 993    Harold      M                 2
# 994    Victor      M                 5
# 995   Charles      M                 1
# 996    August      F                 4
# 997  Victoria      F                 5
# 998      Mike      M                 3

# %% [markdown]
# 6. Complete the code below to re-import the <b>axisdata.csv</b> file as "sales". This time, change the index from the default to the column "Lname".

# %%
sales2 = pd.read_csv("axisdata.csv", index_col = "Lname")

# %% [markdown]
# 7. Write the code to examine the first 5 rows of the sales dataset. Is the index the column that you wanted?

# %%
sales2.head()
# Out:
#              Fname Gender  Hours Worked SalesTraining  Years Experience  \
# Lname
# Walters       Jada      F            39             N                 3
# Henderson   Nicole      F            46             N                 3
# Moore        Tanya      F            42             Y                 4
# Jackson    Ronelle      F            38             Y                 5
# Sears         Brad      M            33             N                 4
#
#            Cars Sold
# Lname
# Walters            2
# Henderson          6
# Moore              6
# Jackson            3
# Sears              2

# %% [markdown]
# 8. Select the row with the index label "Monroe" using the loc operation. How many sales people have not completed sales training?

# %%
sales2.loc['Monroe']

sales2.loc['Monroe', 'SalesTraining']

# 8
# Out:
# Lname
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    N
# Monroe    N
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    N
# Monroe    N
# Monroe    Y
# Monroe    Y
# Monroe    Y
# Monroe    N
# Monroe    N
# Monroe    Y
# Monroe    Y
# Monroe    N
# Monroe    N
# Name: SalesTraining, dtype: object

# %% [markdown]
# 9. Select the row with the index label "Sears" and the columns "Gender" and "Hours Worked", using the loc operation. How many hours did the first two sales people work?

# %%
sales2.loc['Sears', ['Gender', 'Hours Worked']]

# 33 and 41
# Out:
#       Gender  Hours Worked
# Lname
# Sears      M            33
# Sears      M            41
# Sears      M            43
# Sears      M            44
# Sears      M            37
# Sears      F            26
# Sears      M            33
# Sears      M            28
# Sears      F            45
# Sears      F            37
# Sears      F            28
# Sears      M            25
# Sears      F            34
# Sears      M            33
# Sears      F            40
# Sears      M            20
# Sears      F            44
# Sears      M            43
# Sears      F            48
# Sears      M            36
# Sears      M            26
# Sears      M            29
# Sears      F            40
# Sears      F            22
# Sears      F            28
# Sears      F            22
# Sears      F            37
# Sears      M            29
# Sears      F            47
# Sears      F            20

# %% [markdown]
# 10. Select the columns "Fname" and "Years Experience" for all rows using the loc operation.

# %%
sales2.loc[:, ['Fname', 'Years Experience']]
# Out:
#               Fname  Years Experience
# Lname
# Walters        Jada                 3
# Henderson    Nicole                 3
# Moore         Tanya                 4
# Jackson     Ronelle                 5
# Sears          Brad                 4
# ...             ...               ...
# Kane         Victor                 5
# Turner      Charles                 1
# Franklin     August                 4
# Rogers     Victoria                 5
# Gerardo        Mike                 3
#
# [999 rows x 2 columns]

# %% [markdown]
# ## Exporting Data

# %% [markdown]
# 1. Export your "sales" dataset to a .csv file called "Module 1".

# %%
sales.to_csv('Module1.csv', index = False)
test = pd.read_csv('Module1.csv')
test.head()
# Out:
#      Fname      Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 0     Jada   Walters       F            39             N                 3
# 1   Nicole  Henderson      F            46             N                 3
# 2    Tanya      Moore      F            42             Y                 4
# 3  Ronelle    Jackson      F            38             Y                 5
# 4     Brad      Sears      M            33             N                 4
#
#    Cars Sold
# 0          2
# 1          6
# 2          6
# 3          3
# 4          2

# %% [markdown]
# #  Well Done!!

# %% [markdown]
# ## * ~ Homework ~ *
#
# Find a dataset online and import it into a new notebook. Once you have your data imported, play around with the functions that you've learned thus far. What information can you find out about your dataset? Write a brief summary about the characteristics of your dataset: what kind of data was collected, how large is the dataset, how many columns/rows, what are the names of the columns, what types of data are included in the dataset, etc. Can you isolate a slice of your data and export it to a new .csv file? Send the completed notebook and your data file to me through Canvas Messaging.
#
# <b> DUE DATE:</b> Friday, Feb 14
#
#
# <i> All homework assignments are counted towards a percentage of your participation grade.</i>

# %%
import pandas as pd
import numpy as np

# %%
sm = pd.read_excel('Supermarket Data.xlsx')

sm.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715 2019-01-05
# 1  Electronic accessories       15.28         5   3.8200   80.2200 2019-03-08
# 2      Home and lifestyle       46.33         7  16.2155  340.5255 2019-03-03
# 3       Health and beauty       58.22         8  23.2880  489.0480 2019-01-27
# 4       Sports and travel       86.31         7  30.2085  634.3785 2019-02-08
#
#        Time      Payment    cogs  gross margin percentage  gross income  \
# 0  13:08:00      Ewallet  522.83                 4.761905       26.1415
# 1  10:29:00         Cash   76.40                 4.761905        3.8200
# 2  13:23:00  Credit card  324.31                 4.761905       16.2155
# 3  20:33:00      Ewallet  465.76                 4.761905       23.2880
# 4  10:37:00      Ewallet  604.17                 4.761905       30.2085
#
#    Rating
# 0     9.1
# 1     9.6
# 2     7.4
# 3     8.4
# 4     5.3

# %%
sm.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
sm.max()
# Out:
# Invoice ID                         898-04-2717
# Branch                                       C
# City                                    Yangon
# Customer type                           Normal
# Gender                                    Male
# Product line                 Sports and travel
# Unit price                               99.96
# Quantity                                    10
# Tax 5%                                   49.65
# Total                                  1042.65
# Date                       2019-03-30 00:00:00
# Time                                  20:59:00
# Payment                                Ewallet
# cogs                                     993.0
# gross margin percentage               4.761905
# gross income                             49.65
# Rating                                    10.0
# dtype: object

# %%
pd.pivot_table(sm, index = ['Payment'])
# Out:
# <ipython-input-36-43abf4339ab4>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(sm, index = ['Payment'])
#              Quantity    Rating     Tax 5%       Total  Unit price  \
# Payment
# Cash         5.511628  6.970058  15.532471  326.181890   56.758983
# Credit card  5.536977  7.003215  15.429042  324.009878   54.394469
# Ewallet      5.484058  6.947826  15.181933  318.820600   55.740174
#
#                    cogs  gross income  gross margin percentage
# Payment
# Cash         310.649419     15.532471                 4.761905
# Credit card  308.580836     15.429042                 4.761905
# Ewallet      303.638667     15.181933                 4.761905

# %%
pd.pivot_table(sm, index = ['Branch'], values = ['Quantity'])
# Out:
#         Quantity
# Branch
# A       5.467647
# B       5.481928
# C       5.582317

# %%
pd.pivot_table(sm, index = ['Branch'], values = ['Total'], columns = ['Quantity'])
# Out:
#               Total                                                  \
# Quantity         1           2           3           4           5
# Branch
# A         56.373333  118.144500  183.970191  231.123730  264.499773
# B         62.832000  116.931182  168.888125  212.237846  291.570000
# C         54.597375  127.600900  187.336800  255.123273  241.648750
#
#
# Quantity          6           7          8           9           10
# Branch
# A         375.573484  394.062083  517.01664  504.227613  527.180132
# B         366.600500  431.418750  469.29400  539.581103  558.477500
# C         310.155097  457.860513  443.73560  548.394000  662.020333

# %%
pd.pivot_table(sm, index = ['Branch'], values = ['Total'], aggfunc = [np.mean, np.median, min, max, np.std, 'count', np.sum])
# Out:
#               mean     median      min      max         std count          sum
#              Total      Total    Total    Total       Total Total        Total
# Branch
# A       312.354031  240.82800  12.6945  1039.29  231.640025   340  106200.3705
# B       319.872506  252.88200  18.6375  1022.49  242.447565   332  106197.6720
# C       337.099715  271.41975  10.6785  1042.65  263.160870   328  110568.7065
