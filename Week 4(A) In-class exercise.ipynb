# %%
import pandas as pd
import numpy as np

# always import pandas and numpy

# %%
df = pd.read_excel('axisdata.xlsx')
df.head()

# import axisdata
# Out:
#     Fname      Lname Position Gender  Hours Worked SalesTraining  \
# 0  Jackie    Jackson  Trainee      F            32             Y
# 1    Mary  Patterson  Trainee      F            43             N
# 2   Tanya      Adams  Trainee      F            28             Y
# 3   Tanya  Henderson  Trainee      F            24             Y
# 4  Walter   Franklin  Trainee      M            25             Y
#
#    Years Experience  Cars Sold
# 0                 1          3
# 1                 1          6
# 2                 1          2
# 3                 1          5
# 4                 1          4

# %%
df.to_excel('sales_excel.xlsx')
test = pd.read_excel('sales_excel.xlsx')
test.head()

# export the data to excel
# Out:
#    Unnamed: 0   Fname      Lname Position Gender  Hours Worked SalesTraining  \
# 0           0  Jackie    Jackson  Trainee      F            32             Y
# 1           1    Mary  Patterson  Trainee      F            43             N
# 2           2   Tanya      Adams  Trainee      F            28             Y
# 3           3   Tanya  Henderson  Trainee      F            24             Y
# 4           4  Walter   Franklin  Trainee      M            25             Y
#
#    Years Experience  Cars Sold
# 0                 1          3
# 1                 1          6
# 2                 1          2
# 3                 1          5
# 4                 1          4

# %%
df.tail(2)

# show the last two rows
# Out:
#         Fname   Lname            Position Gender  Hours Worked SalesTraining  \
# 997    Victor    Kane  Senior Salesperson      M            22             Y
# 998  Victoria  Rogers  Senior Salesperson      F            29             N
#
#      Years Experience  Cars Sold
# 997                 5          4
# 998                 5          1

# %%
df.columns

# get the columns headers
# Out:
# Index(['Fname', 'Lname', 'Position', 'Gender', 'Hours Worked', 'SalesTraining',
#        'Years Experience', 'Cars Sold'],
#       dtype='object')

# %%
df.dtypes

# print the data type for all columns in your dataset
# Out:
# Fname               object
# Lname               object
# Position            object
# Gender              object
# Hours Worked         int64
# SalesTraining       object
# Years Experience     int64
# Cars Sold            int64
# dtype: object

# %%
df.describe()

# how spread out is the data?
# Out:
#        Hours Worked  Years Experience   Cars Sold
# count    999.000000        999.000000  999.000000
# mean      33.727728          3.026026    3.922923
# std        8.223454          1.394709    1.527000
# min       20.000000          1.000000    1.000000
# 25%       27.000000          2.000000    3.000000
# 50%       34.000000          3.000000    4.000000
# 75%       41.000000          4.000000    5.000000
# max       48.000000          5.000000    7.000000

# %%
df.info()

# all of them have values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Fname             999 non-null    object
#  1   Lname             999 non-null    object
#  2   Position          999 non-null    object
#  3   Gender            999 non-null    object
#  4   Hours Worked      999 non-null    int64
#  5   SalesTraining     999 non-null    object
#  6   Years Experience  999 non-null    int64
#  7   Cars Sold         999 non-null    int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.max()

# The max letter for Position is 'T' for Trainee
# Out:
# Fname                 india
# Lname               Withers
# Position            Trainee
# Gender                    M
# Hours Worked             48
# SalesTraining             Y
# Years Experience          5
# Cars Sold                 7
# dtype: object

# %%
df['Years Experience'].min()
# what is the least number of experience?
# Out:
# 1

# %%
df['Position'].value_counts()

# how many employees fall within each position group?
# Out:
# Junior Salesperson    419
# Senior Salesperson    397
# Trainee               183
# Name: Position, dtype: int64

# %%
pd.crosstab(df['Position'], df['Gender'])

# how many females and males in junior salesperson position?
# Out:
# Gender                F    M
# Position
# Junior Salesperson  204  215
# Senior Salesperson  200  197
# Trainee              85   98

# %%
pd.pivot_table(df, index = ['Position'])

# if you do not specify, it automatically shows you the average by default
# on average, how many years experience, cars sold, and hours worked in each position?
# Out:
# <ipython-input-21-8432d88acd6d>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index = ['Position'])
#                     Cars Sold  Hours Worked  Years Experience
# Position
# Junior Salesperson   3.928401     34.066826          2.505967
# Senior Salesperson   4.005038     33.692695          4.508816
# Trainee              3.732240     33.027322          1.000000

# %%
pd.pivot_table(df, index = ['Position', 'SalesTraining'], values = ['Cars Sold'])
# Out:
#                                   Cars Sold
# Position           SalesTraining
# Junior Salesperson N               3.548780
#                    Y               4.172549
# Senior Salesperson N               3.538012
#                    Y               4.358407
# Trainee            N               3.705128
#                    Y               3.752381

# %%
df.groupby(df['Gender']).mean()

# on average, how many years, experience, cars sold, and hours worked do the employees have by gender?
# Out:
# <ipython-input-26-bf1f262ec101>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(df['Gender']).mean()
#         Hours Worked  Years Experience  Cars Sold
# Gender
# F          33.693252          3.049080   3.760736
# M          33.760784          3.003922   4.078431

# %%
df['Cars Sold'].groupby (df['Position']).mean()

# on average, how many cars are sold by sales position?
# Out:
# Position
# Junior Salesperson    3.928401
# Senior Salesperson    4.005038
# Trainee               3.732240
# Name: Cars Sold, dtype: float64

# %%
df[['Hours Worked', 'Cars Sold']].groupby(df['SalesTraining']).mean()

# group both Hours Worked and Cars Sold by SalesTraining
# do people who have sales training and work more hours, sell more cars?
# Out:
#                Hours Worked  Cars Sold
# SalesTraining
# N                 33.474576   3.573850
# Y                 33.906143   4.168942

# %%
df.loc[df['Hours Worked'] >= 40]

# who is working more than or equal to 40 hours?
# Out:
#       Fname      Lname            Position Gender  Hours Worked SalesTraining  \
# 1      Mary  Patterson             Trainee      F            43             N
# 6    Martin   Ettienne             Trainee      M            42             N
# 7     Peter   Michaels             Trainee      M            43             N
# 10      Sam   Michaels             Trainee      M            45             Y
# 13    Tanya     Carter             Trainee      F            40             Y
# ..      ...        ...                 ...    ...           ...           ...
# 984    Lisa     Carter  Senior Salesperson      F            40             Y
# 989   Onika      Sears  Senior Salesperson      F            47             N
# 990     Sam  Samuelson  Senior Salesperson      M            43             Y
# 993  Walter    Martins  Senior Salesperson      M            41             N
# 994  Walter    Mulgrew  Senior Salesperson      M            40             Y
#
#      Years Experience  Cars Sold
# ...
