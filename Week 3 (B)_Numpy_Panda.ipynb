# %%
import pandas as pd # data analysis functions

import numpy as np # mathematical function

# %%
df = pd.read_csv("/content/pokemon.csv")
# if the name of the file is too long, copy path from the folder icon

df.head()
# Out:
#    Num        Name Type 1  Type 2  Total  HP  Attack  Defense  SpAtk  SpDef  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49     65     65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63     80     80
# 2    3    Venusaur  Grass  Poison    525  80      82       83    100    100
# 3    4  Charmander   Fire     NaN    309  39      52       43     60     50
# 4    5  Charmeleon   Fire     NaN    405  58      64       58     80     65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df.to_excel("pokemon_excel.xlsx")

# exporting the data to excel
# don't forget the xlsx at the end
# inside of "" is the name you are giving the file

# %%
poke_excel = pd.read_excel("pokemon_excel.xlsx")

poke_excel.head()

# check your exported data by importing the data back
# Out:
#    Unnamed: 0  Num        Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0           0    1   Bulbasaur  Grass  Poison    318  45      49       49
# 1           1    2     Ivysaur  Grass  Poison    405  60      62       63
# 2           2    3    Venusaur  Grass  Poison    525  80      82       83
# 3           3    4  Charmander   Fire     NaN    309  39      52       43
# 4           4    5  Charmeleon   Fire     NaN    405  58      64       58
#
#    SpAtk  SpDef  Speed  Stage  Legendary
# 0     65     65     45      1      False
# 1     80     80     60      2      False
# 2    100    100     80      3      False
# 3     60     50     65      1      False
# 4     80     65     80      2      False

# %%
df.tail(2)

# the bottom two rows from the dataset
# Out:
#      Num    Name   Type 1 Type 2  Total   HP  Attack  Defense  SpAtk  SpDef  \
# 149  150  Mewtwo  Psychic    NaN    680  106     110       90    154     90
# 150  151     Mew  Psychic    NaN    600  100     100      100    100    100
#
#      Speed  Stage  Legendary
# 149    130      1       True
# 150    100      1      False

# %%
df.columns

# gives you the list of column names
# Out:
# Index(['Num', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'SpAtk', 'SpDef', 'Speed', 'Stage', 'Legendary'],
#       dtype='object')

# %%
df.dtypes

# types of eacg column (object vs integer)
# Out:
# Num           int64
# Name         object
# Type 1       object
# Type 2       object
# Total         int64
# HP            int64
# Attack        int64
# Defense       int64
# SpAtk         int64
# SpDef         int64
# Speed         int64
# Stage         int64
# Legendary      bool
# dtype: object

# %%
df.max()

# highest value of each column
# Zubat because z is the highest value
# Out:
# <ipython-input-19-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Num            151
# Name         Zubat
# Type 1       Water
# Total          680
# HP             250
# Attack         134
# Defense        180
# SpAtk          154
# SpDef          125
# Speed          140
# Stage            3
# Legendary     True
# dtype: object

# %%
df['Attack'].sum()

# categorical variable sum -- combine all values to one
# Out:
# 10955

# %%
df.mean()

# the average
# Out:
# <ipython-input-22-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Num           76.000000
# Total        407.079470
# HP            64.211921
# Attack        72.549669
# Defense       68.225166
# SpAtk         67.139073
# SpDef         66.019868
# Speed         68.933775
# Stage          1.582781
# Legendary      0.026490
# dtype: float64

# %%
df.median()

# middle value
# Out:
# <ipython-input-23-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Num           76.0
# Total        405.0
# HP            60.0
# Attack        70.0
# Defense       65.0
# SpAtk         65.0
# SpDef         65.0
# Speed         70.0
# Stage          1.0
# Legendary      0.0
# dtype: float64

# %%
df.mode()

# mode is the value that occur the most frequently
# ignore the - that is the index value, not another mode
# Out:
#      Num     Name Type 1  Type 2  Total    HP  Attack  Defense  SpAtk  SpDef  \
# 0      1  Nidoran  Water  Flying  405.0  65.0    65.0     65.0   50.0   80.0
# 1      2      NaN    NaN  Poison  490.0   NaN     NaN      NaN   65.0    NaN
# 2      3      NaN    NaN     NaN  500.0   NaN     NaN      NaN    NaN    NaN
# 3      4      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# 4      5      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# ..   ...      ...    ...     ...    ...   ...     ...      ...    ...    ...
# 146  147      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# 147  148      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# 148  149      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# 149  150      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
# 150  151      NaN    NaN     NaN    NaN   NaN     NaN      NaN    NaN    NaN
#
#      Speed  Stage Legendary
# 0     70.0    1.0     False
# 1     90.0    NaN       NaN
# 2      NaN    NaN       NaN
# 3      NaN    NaN       NaN
# 4      NaN    NaN       NaN
# ..     ...    ...       ...
# 146    NaN    NaN       NaN
# 147    NaN    NaN       NaN
# 148    NaN    NaN       NaN
# 149    NaN    NaN       NaN
# 150    NaN    NaN       NaN
#
# [151 rows x 13 columns]

# %%
df['Attack'].std()

# determine the standard deviation of a specific column
# a measure of how spread out the values are
# Out:
# 26.59616231507141

# %%
df['Type 1'].value_counts()

# determine how often each unique value occurs within a specific column
# Out:
# Water       28
# Normal      22
# Poison      14
# Grass       12
# Fire        12
# Bug         12
# Electric     9
# Rock         9
# Ground       8
# Psychic      8
# Fighting     7
# Ghost        3
# Dragon       3
# Fairy        2
# Ice          2
# Name: Type 1, dtype: int64

# %%
pd.crosstab(df['Type 1'], df['Legendary'])

# how many of each type is legendary?
# true = the number of legendary --- false = the number of non-legendary
# Out:
# Legendary  False  True
# Type 1
# Bug           12      0
# Dragon         3      0
# Electric       8      1
# Fairy          2      0
# Fighting       7      0
# Fire          11      1
# Ghost          3      0
# Grass         12      0
# Ground         8      0
# Ice            1      1
# Normal        22      0
# Poison        14      0
# Psychic        7      1
# Rock           9      0
# Water         28      0

# %%
pd.pivot_table(df, index = ['Type 1'])

# basic pivot table by default, the aggregate variable will display the 'mean'
# will aggregate all numeric columns
# Out:
# <ipython-input-33-e40f9fe60da7>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   pd.pivot_table(df, index = ['Type 1'])
#               Attack     Defense         HP  Legendary         Num  \
# Type 1
# Bug        63.750000   57.083333  55.416667   0.000000   42.916667
# Dragon     94.000000   68.333333  64.333333   0.000000  148.000000
# Electric   62.000000   64.666667  54.444444   0.111111   91.111111
# Fairy      57.500000   60.500000  82.500000   0.000000   35.500000
# Fighting  102.857143   61.000000  63.571429   0.000000   75.285714
# Fire       83.916667   62.583333  63.833333   0.083333   64.166667
# Ghost      50.000000   45.000000  45.000000   0.000000   93.000000
# Grass      70.666667   69.583333  65.000000   0.000000   55.583333
# Ground     81.875000   86.250000  58.125000   0.000000   73.500000
# Ice        67.500000   67.500000  77.500000   0.500000  134.000000
# Normal     67.727273   53.545455  78.681818   0.000000   71.727273
# Poison     74.428571   67.000000  64.500000   0.000000   51.071429
# Psychic    60.125000   57.500000  63.875000   0.125000  101.000000
# Rock       82.222222  110.000000  53.888889   0.000000  113.333333
# Water      70.250000   77.500000  64.535714   0.000000   85.928571
#
#                SpAtk       SpDef      Speed     Stage       Total
# Type 1
# Bug        47.500000   55.416667  57.083333  1.666667  336.250000
# Dragon     73.333333   73.333333  66.666667  2.000000  440.000000
# Electric   91.111111   73.333333  98.888889  1.444444  444.444444
# Fairy      77.500000   77.500000  47.500000  1.500000  403.000000
# Fighting   45.000000   73.571429  66.142857  1.571429  412.142857
# Fire       84.583333   76.666667  84.000000  1.583333  455.583333
# Ghost     115.000000   55.000000  95.000000  2.000000  405.000000
# Grass      87.916667   64.166667  52.083333  1.833333  409.416667
# Ground     39.375000   50.625000  58.125000  1.500000  374.375000
# Ice       105.000000  110.000000  90.000000  1.000000  517.500000
# Normal     51.272727   59.863636  69.318182  1.363636  380.409091
# Poison     57.142857   61.642857  58.785714  1.714286  383.500000
# Psychic   103.750000   91.875000  93.000000  1.500000  470.125000
# Rock       60.555556   55.555556  58.333333  1.555556  420.555556
# Water      64.821429   66.392857  67.714286  1.607143  411.214286

# %%
pd.pivot_table(df, index = ['Type 1'], values = ['Attack'])

# basic pivot table - by default, the aggregate variables will display the 'mean'
# will aggregate only Attack column
# Out:
#               Attack
# Type 1
# Bug        63.750000
# Dragon     94.000000
# Electric   62.000000
# Fairy      57.500000
# Fighting  102.857143
# Fire       83.916667
# Ghost      50.000000
# Grass      70.666667
# Ground     81.875000
# Ice        67.500000
# Normal     67.727273
# Poison     74.428571
# Psychic    60.125000
# Rock       82.222222
# Water      70.250000

# %%
pd.pivot_table(df, index = ['Name'], values = ['Speed'])

# mean for each values of the 'Name' column
# Out:
#             Speed
# Name
# Abra         90.0
# Aerodactyl  130.0
# Alakazam    120.0
# Arbok        80.0
# Arcanine     95.0
# ...           ...
# Weepinbell   55.0
# Weezing      60.0
# Wigglytuff   45.0
# Zapdos      100.0
# Zubat        55.0
#
# [150 rows x 1 columns]

# %%
pd.pivot_table(df, index = ['Type 1'], values = ['Attack'], columns = ['Stage'])

# will aggregate only the attack column
# output is further grouped by the stage column
# shows the average attack for each type at each stage
# Out:
#              Attack
# Stage             1           2      3
# Type 1
# Bug       70.833333   51.250000   67.5
# Dragon    64.000000   84.000000  134.0
# Electric  58.600000   66.250000    NaN
# Fairy     45.000000   70.000000    NaN
# Fighting  96.250000  102.500000  130.0
# Fire      73.833333   96.000000   84.0
# Ghost     35.000000   50.000000   65.0
# Grass     53.800000   78.000000   89.0
# Ground    66.250000   97.500000    NaN
# Ice       67.500000         NaN    NaN
# Normal    61.933333   80.166667   80.0
# Poison    59.000000   82.333333   97.0
# Psychic   64.600000   54.000000   50.0
# Rock      70.000000   90.000000  120.0
# Water     55.153846   82.461538   89.0

# %%
pd.pivot_table(df, index = ['Type 1'], values = ['Attack'], aggfunc = [np.mean, np.median, min, max, np.std, 'count', np.sum])

# include the aggfunc = to specify the types of output you want to see instead of just seeing the mean
# Out:
#                 mean median    min    max        std  count    sum
#               Attack Attack Attack Attack     Attack Attack Attack
# Type 1
# Bug        63.750000   60.0     20    125  34.910600     12    765
# Dragon     94.000000   84.0     64    134  36.055513      3    282
# Electric   62.000000   60.0     30     90  22.271057      9    558
# Fairy      57.500000   57.5     45     70  17.677670      2    115
# Fighting  102.857143  105.0     80    130  18.676443      7    720
# Fire       83.916667   84.5     41    130  25.152113     12   1007
# Ghost      50.000000   50.0     35     65  15.000000      3    150
# Grass      70.666667   70.0     40    105  20.379728     12    848
# Ground     81.875000   80.0     50    130  25.204521      8    655
# Ice        67.500000   67.5     50     85  24.748737      2    135
# Normal     67.727273   62.5      5    110  24.892496     22   1490
# Poison     74.428571   76.0     45    105  19.214235     14   1042
# Psychic    60.125000   49.0     20    110  31.538808      8    481
# Rock       82.222222   80.0     40    120  29.273613      9    740
# Water      70.250000   66.0     10    130  25.970960     28   1967

# %%
df.groupby(df['Stage']).mean()

# group your entire dataset by the 'Stage' column
# output the mean for each numeric variable by stage
# makes the most sense to group by categorical variable
# Out:
# <ipython-input-12-f4e9d297abbf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(df['Stage']).mean()
#              Num       Total         HP     Attack    Defense      SpAtk  \
# Stage
# 1      85.632911  360.734177  57.708861  63.696203  60.797468  57.202532
# 2      70.589286  446.660714  69.642857  80.107143  75.964286  74.910714
# 3      47.375000  497.375000  77.312500  89.812500  77.812500  89.000000
#
#            SpDef      Speed  Legendary
# Stage
# 1      58.594937  62.734177   0.050633
# 2      71.250000  74.785714   0.000000
# 3      84.375000  79.062500   0.000000

# %%
df['Defense'].groupby(df['Stage']).mean()

# group the 'Defense' variable by the 'Stage' variable
# output the mean defense for each stage
# Out:
# Stage
# 1    60.797468
# 2    75.964286
# 3    77.812500
# Name: Defense, dtype: float64

# %%
df["Defense"].groupby(df['Type 1']).min()

# group the 'Defense' variable by the "Type 1" variable
# output the minimum defense for each pokemon type
# Out:
# Type 1
# Bug         30
# Dragon      45
# Electric    40
# Fairy       48
# Fighting    35
# Fire        40
# Ghost       30
# Grass       35
# Ground      25
# Ice         35
# Normal       5
# Poison      35
# Psychic     15
# Rock        65
# Water       35
# Name: Defense, dtype: int64

# %%
df[['Defense', 'Attack']].groupby(df['Stage']).mean()

# group both the "Defense" and "Attack" variables by "Stage"
# output the average defense and attack for each stage
# Out:
#          Defense     Attack
# Stage
# 1      60.797468  63.696203
# 2      75.964286  80.107143
# 3      77.812500  89.812500

# %%
speed_100 = df.loc[df['Speed'] == 100]
speed_100
# Out:
#      Num        Name    Type 1  Type 2  Total   HP  Attack  Defense  SpAtk  \
# 5      6   Charizard      Fire  Flying    534   78      84       78    109
# 21    22      Fearow    Normal  Flying    442   65      90       65     61
# 37    38   Ninetales      Fire     NaN    505   73      76       75     81
# 72    73  Tentacruel     Water  Poison    515   80      70       65     80
# 84    85      Dodrio    Normal  Flying    460   60     110       70     60
# 99   100     Voltorb  Electric     NaN    330   40      30       50     55
# 144  145      Zapdos  Electric  Flying    580   90      90       85    125
# 150  151         Mew   Psychic     NaN    600  100     100      100    100
#
#      SpDef  Speed  Stage  Legendary
# 5       85    100      3      False
# 21      61    100      2      False
# 37     100    100      2      False
# 72     120    100      2      False
# 84      60    100      2      False
# 99      55    100      1      False
# 144     90    100      1       True
# 150    100    100      1      False

# %%
speed_lt100 = df.loc[df['Speed'] < 100]
speed_lt100 = speed_lt100.loc[speed_lt100['Attack'] >= 50]
speed_lt100
# Out:
#      Num        Name  Type 1  Type 2  Total  HP  Attack  Defense  SpAtk  \
# 1      2     Ivysaur   Grass  Poison    405  60      62       63     80
# 2      3    Venusaur   Grass  Poison    525  80      82       83    100
# 3      4  Charmander    Fire     NaN    309  39      52       43     60
# 4      5  Charmeleon    Fire     NaN    405  58      64       58     80
# 7      8   Wartortle   Water     NaN    405  59      63       80     65
# ..   ...         ...     ...     ...    ...  ..     ...      ...    ...
# 143  144    Articuno     Ice  Flying    580  90      85      100     95
# 145  146     Moltres    Fire  Flying    580  90     100       90    125
# 146  147     Dratini  Dragon     NaN    300  41      64       45     50
# 147  148   Dragonair  Dragon     NaN    420  61      84       65     70
# 148  149   Dragonite  Dragon  Flying    600  91     134       95    100
#
#      SpDef  Speed  Stage  Legendary
# 1       80     60      2      False
# 2      100     80      3      False
# 3       50     65      1      False
# 4       65     80      2      False
# 7       80     58      2      False
# ..     ...    ...    ...        ...
# 143    125     85      1       True
# 145     85     90      1       True
# 146     50     50      1      False
# 147     70     70      2      False
# 148    100     80      3      False
#
# [98 rows x 13 columns]

# %%
df.loc[(df["Speed"] >= 50) & (df["Attack"] == 100)]
# Out:
#      Num       Name   Type 1  Type 2  Total   HP  Attack  Defense  SpAtk  \
# 27    28  Sandslash   Ground     NaN    450   75     100      110     45
# 77    78   Rapidash     Fire     NaN    500   65     100       70     80
# 127  128     Tauros   Normal     NaN    490   75     100       95     40
# 145  146    Moltres     Fire  Flying    580   90     100       90    125
# 150  151        Mew  Psychic     NaN    600  100     100      100    100
#
#      SpDef  Speed  Stage  Legendary
# 27      55     65      2      False
# 77      80    105      2      False
# 127     70    110      1      False
# 145     85     90      1       True
# 150    100    100      1      False

# %%
df.loc[(df["Type 1"] == "Ghost") | (df["Type 1"] == "Ice")]

# a single bar means "OR"
# Out:
#      Num      Name Type 1   Type 2  Total  HP  Attack  Defense  SpAtk  SpDef  \
# 91    92    Gastly  Ghost   Poison    310  30      35       30    100     35
# 92    93   Haunter  Ghost   Poison    405  45      50       45    115     55
# 93    94    Gengar  Ghost   Poison    500  60      65       60    130     75
# 123  124      Jynx    Ice  Psychic    455  65      50       35    115     95
# 143  144  Articuno    Ice   Flying    580  90      85      100     95    125
#
#      Speed  Stage  Legendary
# 91      80      1      False
# 92      95      2      False
# 93     110      3      False
# 123     95      1      False
# 143     85      1       True

# %%
df.isnull().sum()

# Missing Data - does my dataset have ANY missing data?
# the output will show how many 'missing' values are within that specific column
# Out:
# Num           0
# Name          0
# Type 1        0
# Type 2       84
# Total         0
# HP            0
# Attack        0
# Defense       0
# SpAtk         0
# SpDef         0
# Speed         0
# Stage         0
# Legendary     0
# dtype: int64

# %%
df_missing = df["Type 2"].isnull()

# What if you want to identify the specific rows that are missing for a specific column?
# locating rows with missing values

# create a dataset that shows where Type 2 is missing;
# this will show up as a (true/false) list

df_missing.head()

# output the first few rows of this dataset
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: Type 2, dtype: bool

# %%
df.loc[df_missing]

# next, use the .loc function to output the instances where df_missing == True
# Out:
#      Num        Name   Type 1 Type 2  Total   HP  Attack  Defense  SpAtk  \
# 3      4  Charmander     Fire    NaN    309   39      52       43     60
# 4      5  Charmeleon     Fire    NaN    405   58      64       58     80
# 6      7    Squirtle    Water    NaN    314   44      48       65     50
# 7      8   Wartortle    Water    NaN    405   59      63       80     65
# 8      9   Blastoise    Water    NaN    530   79      83      100     85
# ..   ...         ...      ...    ...    ...  ...     ...      ...    ...
# 142  143     Snorlax   Normal    NaN    540  160     110       65     65
# 146  147     Dratini   Dragon    NaN    300   41      64       45     50
# 147  148   Dragonair   Dragon    NaN    420   61      84       65     70
# 149  150      Mewtwo  Psychic    NaN    680  106     110       90    154
# 150  151         Mew  Psychic    NaN    600  100     100      100    100
#
#      SpDef  Speed  Stage  Legendary
# 3       50     65      1      False
# 4       65     80      2      False
# 6       64     43      1      False
# 7       80     58      2      False
# 8      105     78      3      False
# ..     ...    ...    ...        ...
# 142    110     30      1      False
# 146     50     50      1      False
# 147     70     70      2      False
# 149     90    130      1       True
# 150    100    100      1      False
#
# [84 rows x 13 columns]

# %%
dupes = pd.read_csv('/content/pokemon_dupe.csv')
dupes.head()

# uploading new dataset to find duplicates
# Out:
#    Num        Name Type 1  Type 2  Total  HP  Attack  Defense  SpAtk  SpDef  \
# 0    1   Bulbasaur  Grass  Poison    318  45      49       49     65     65
# 1    2     Ivysaur  Grass  Poison    405  60      62       63     80     80
# 2    3    Venusaur  Grass  Poison    525  80      82       83    100    100
# 3    4  Charmander   Fire     NaN    309  39      52       43     60     50
# 4    5  Charmeleon   Fire     NaN    405  58      64       58     80     65
#
#    Speed  Stage  Legendary
# 0     45      1      False
# 1     60      2      False
# 2     80      3      False
# 3     65      1      False
# 4     80      2      False

# %%
df_dupes = dupes.duplicated()

# use the .duplicated() function to check the entire dataset for duplicate rows (ALL values must match to be considered a duplicate)
# create a dataset that shows the rows where the data is duplicated; this will show up as a boolen (true/false) list
